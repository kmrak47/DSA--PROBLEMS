# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
df = pd.read_excel("Messy_Media_Campaign_dataset.xlsx")
df.head()
# Out:
#          Date   Campaign_Name        Theme  Channel Sub_Channel  \
# 0  2025-01-01     Winter Sale    Discounts  Digital    Facebook
# 1  01/02/2025    winter sale     discounts  Digital   Instagram
# 2  2025/03/01   Summer Launch  New Product       TV         NaN
# 3  2025-04-01   Summer Launch  New Product       tv  Prime Time
# 4  2025-05-01  Brand Campaign     Branding      OLV     Youtube
#
#   Communication_Objective Audience   Vendor  Impressions Clicks  Media_Cost  \
# 0               Awareness   Adults     Meta     120000.0   2500       15000
# 1               Awareness   adults     meta     130000.0   2700       16000
# 2                   Reach      All  Star TV    5000000.0    NaN      250000
# 3                   Reach      ALL  star tv    5100000.0   1000      255000
# 4           Consideration    Youth   Google     800000.0  12000       45000
#
#    Production_Cost  Agency_Fee  Platform_Fee
# 0           2000.0      1000.0         500.0
# ...

# %%
df.sample(5)
# Out:
#           Date   Campaign_Name      Theme  Channel Sub_Channel  \
# 5   05-06-2025  Brand Campaign   branding      OLV     YouTube
# 10  2025-11-01     Diwali Sale   Festival  Digital   Instagram
# 6   2025-07-01   Festive Blast   Festival  Digital    Facebook
# 7   2025-08-01   Festive Blast   Festival  Digital    facebook
# 13  2026-01-01    Republic Day  Patriotic    Radio          FM
#
#    Communication_Objective Audience        Vendor  Impressions Clicks  \
# 5            Consideration   youth         google     820000.0  12500
# 10              Conversion   Adults           NaN     160000.0   3400
# 6               Conversion   Adults          Meta          NaN   3000
# 7               Conversion   Adults          Meta     145000.0    abc
# 13               Awareness   Adults  Radio Mirchi     250000.0    500
#
#     Media_Cost  Production_Cost  Agency_Fee  Platform_Fee
# 5        46000           5000.0         NaN        1250.0
# ...

# %%
df.shape
# Out:
# (20, 14)

# %%
df.columns
# Out:
# Index(['Date', 'Campaign_Name', 'Theme', 'Channel', 'Sub_Channel',
#        'Communication_Objective', 'Audience', 'Vendor', 'Impressions',
#        'Clicks', 'Media_Cost', 'Production_Cost', 'Agency_Fee',
#        'Platform_Fee'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Date                           str
# Campaign_Name                  str
# Theme                          str
# Channel                        str
# Sub_Channel                    str
# Communication_Objective        str
# Audience                       str
# Vendor                         str
# Impressions                float64
# Clicks                         str
# Media_Cost                   int64
# Production_Cost            float64
# Agency_Fee                 float64
# Platform_Fee               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     20 non-null     str
#  1   Campaign_Name            19 non-null     str
#  2   Theme                    20 non-null     str
#  3   Channel                  20 non-null     str
#  4   Sub_Channel              19 non-null     str
#  5   Communication_Objective  20 non-null     str
#  6   Audience                 19 non-null     str
#  7   Vendor                   19 non-null     str
#  8   Impressions              19 non-null     float64
#  9   Clicks                   19 non-null     str
#  10  Media_Cost               20 non-null     int64
#  11  Production_Cost          19 non-null     float64
#  12  Agency_Fee               19 non-null     float64
#  13  Platform_Fee             19 non-null     float64
# dtypes: float64(4), int64(1), str(9)
# ...

# %%
df.describe(include = 'all')
# Out:
#               Date  Campaign_Name     Theme  Channel Sub_Channel  \
# count           20             19        20       20          19
# unique          19              9        10        5           7
# top     2026-01-01  Summer Launch  Festival  Digital   Instagram
# freq             2              4         6       12           9
# mean           NaN            NaN       NaN      NaN         NaN
# std            NaN            NaN       NaN      NaN         NaN
# min            NaN            NaN       NaN      NaN         NaN
# 25%            NaN            NaN       NaN      NaN         NaN
# 50%            NaN            NaN       NaN      NaN         NaN
# 75%            NaN            NaN       NaN      NaN         NaN
# max            NaN            NaN       NaN      NaN         NaN
#
#        Communication_Objective Audience Vendor   Impressions Clicks  \
# count                       20       19     19  1.900000e+01     19
# ...

# %%
#Null Analysis
df.isnull().sum()
# Out:
# Date                       0
# Campaign_Name              1
# Theme                      0
# Channel                    0
# Sub_Channel                1
# Communication_Objective    0
# Audience                   1
# Vendor                     1
# Impressions                1
# Clicks                     1
# Media_Cost                 0
# Production_Cost            1
# Agency_Fee                 1
# Platform_Fee               1
# dtype: int64

# %%
Percentage_null = (df.isnull().sum()/len(df))*100
Percentage_null
# Out:
# Date                       0.0
# Campaign_Name              5.0
# Theme                      0.0
# Channel                    0.0
# Sub_Channel                5.0
# Communication_Objective    0.0
# Audience                   5.0
# Vendor                     5.0
# Impressions                5.0
# Clicks                     5.0
# Media_Cost                 0.0
# Production_Cost            5.0
# Agency_Fee                 5.0
# Platform_Fee               5.0
# dtype: float64

# %%
#Duplicate Analysis
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#           Date Campaign_Name      Theme Channel Sub_Channel  \
# 13  2026-01-01  Republic Day  Patriotic   Radio          FM
#
#    Communication_Objective Audience        Vendor  Impressions Clicks  \
# 13               Awareness   Adults  Radio Mirchi     250000.0    500
#
#     Media_Cost  Production_Cost  Agency_Fee  Platform_Fee
# 13       10000           1000.0       500.0         250.0

# %%
#unique Values
df.nunique()
# Out:
# Date                       19
# Campaign_Name               9
# Theme                      10
# Channel                     5
# Sub_Channel                 7
# Communication_Objective     4
# Audience                    8
# Vendor                      8
# Impressions                17
# Clicks                     17
# Media_Cost                 17
# Production_Cost             8
# Agency_Fee                  8
# Platform_Fee               12
# dtype: int64

# %%
Percentage_unique = (df.nunique()/len(df))*100
Percentage_unique
# Out:
# Date                       95.0
# Campaign_Name              45.0
# Theme                      50.0
# Channel                    25.0
# Sub_Channel                35.0
# Communication_Objective    20.0
# Audience                   40.0
# Vendor                     40.0
# Impressions                85.0
# Clicks                     85.0
# Media_Cost                 85.0
# Production_Cost            40.0
# Agency_Fee                 40.0
# Platform_Fee               60.0
# dtype: float64

# %%
df['Channel'].value_counts()
# Out:
# Channel
# Digital    12
# OLV         4
# Radio       2
# TV          1
# tv          1
# Name: count, dtype: int64

# %%
#Data Cleaning
#Audience - removing leading and trailing spaces
df['Audience'] = df['Audience'].str.strip()

# %%
obj_cols = df.select_dtypes(include = 'object').columns
df[obj_cols] = df[obj_cols].apply(lambda x:x.str.strip())
# Out:
# /var/folders/sl/ylx38ztj4wn7n_b5mssc94kr0000gn/T/ipykernel_29863/126451047.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_cols = df.select_dtypes(include = 'object').columns

# %%
df.head()
# Out:
#          Date   Campaign_Name        Theme  Channel Sub_Channel  \
# 0  2025-01-01     Winter Sale    Discounts  Digital    Facebook
# 1  01/02/2025     winter sale    discounts  Digital   Instagram
# 2  2025/03/01   Summer Launch  New Product       TV         NaN
# 3  2025-04-01   Summer Launch  New Product       tv  Prime Time
# 4  2025-05-01  Brand Campaign     Branding      OLV     Youtube
#
#   Communication_Objective Audience   Vendor  Impressions Clicks  Media_Cost  \
# 0               Awareness   Adults     Meta     120000.0   2500       15000
# 1               Awareness   adults     meta     130000.0   2700       16000
# 2                   Reach      All  Star TV    5000000.0    NaN      250000
# 3                   Reach      ALL  star tv    5100000.0   1000      255000
# 4           Consideration    Youth   Google     800000.0  12000       45000
#
#    Production_Cost  Agency_Fee  Platform_Fee
# 0           2000.0      1000.0         500.0
# ...

# %%
df.columns = df.columns.str.lower().str.strip()

# %%
df['channel'].value_counts()
# Out:
# channel
# Digital    12
# OLV         4
# Radio       2
# TV          1
# tv          1
# Name: count, dtype: int64
